# %%
from langchain_mistralai import ChatMistralAI
from langchain_core.prompts import ChatPromptTemplate  


llm = ChatMistralAI(api_key="pgAkfuZ0vHpYLPOYrLf6HbpJzrAcr2La", model="mistral-large-latest")

prompt = ChatPromptTemplate.from_template("Summarize this text:\n\n{text}")
chain = prompt | llm

result = chain.invoke({"text": "Your long text here..."})
print(result.content)
# Out:
# Of course! Please provide the text you'd like me to summarize, and I’ll give you a concise and clear summary. You can paste it here, and I’ll focus on the key points.
